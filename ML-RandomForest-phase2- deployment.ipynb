# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalized_model_randomforest.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
result
# Out:
# C:\Users\PAVAN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([47938.381])
