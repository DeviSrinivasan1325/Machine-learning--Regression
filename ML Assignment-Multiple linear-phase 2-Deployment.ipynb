# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalized_model_multiple_linear.sav",'rb'))
result=loaded_model.predict([[1234,6789,7890,0,1]])
result
# Out:
# C:\Users\PAVAN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[44134.28072475]])
